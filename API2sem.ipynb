# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
origem = '/content/drive/My Drive/API/'

# %%
arquivo_1 = origem + 'Acidentes.csv'
arquivo_2 = origem + 'Localidade.csv'
arquivo_3 = origem + 'Vitimas.csv'
arquivo_4 = origem + 'TipoVeiculo.csv'

# %%
Acidentes = pd.read_csv(arquivo_1,low_memory=False,sep=';',encoding='UTF-8')
Localidade = pd.read_csv(arquivo_2,low_memory=False,sep=';',encoding='UTF-8')
Vitimas = pd.read_csv(arquivo_3,low_memory=False,sep=';',encoding='UTF-8')
TipoVeiculo = pd.read_csv(arquivo_4,low_memory=False,sep=';',encoding='UTF-8')

# %%
Acidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3190830 entries, 0 to 3190829
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   numacidente        int64
#  1   chvlocalidade      object
#  2   datacidente        object
#  3   ufacidente         object
#  4   anoacidente        int64
#  5   codigoibge         int64
#  6   diasemana          object
#  7   fasedia            object
#  8   tpacidente         object
#  9   condmeteorologica  object
#  10  tprodovia          object
#  11  condpista          object
#  12  tpcruzamento       object
#  13  tppavimento        object
#  14  tpcurva            object
#  15  limvelocidade      object
#  16  tppista            object
#  17  indguardrail       object
#  18  indcantcentral     object
#  19  indacostamento     object
#  20  qtdeacidente       int64
#  21  qtdeferidosilesos  int64
#  22  qtdeobitos         int64
#  23  qtdeenvolvidos     int64
# dtypes: int64(7), object(17)
# ...

# %%
Localidade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22280 entries, 0 to 22279
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   chvlocalidade        22280 non-null  object
#  1   anoreferencia        22280 non-null  int64
#  2   regiao               22280 non-null  object
#  3   uf                   22280 non-null  object
#  4   codigoibge           22280 non-null  int64
#  5   municipio            22280 non-null  object
#  6   regiaometropolitana  22280 non-null  object
#  7   qtdehabitantes       22280 non-null  int64
#  8   frotatotal           22068 non-null  float64
#  9   frotacirculante      22068 non-null  float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 1.7+ MB

# %%
Vitimas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4951737 entries, 0 to 4951736
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   numacidente        int64
#  1   chvlocalidade      object
#  2   datacidente        object
#  3   ufacidente         object
#  4   anoacidente        int64
#  5   faixaidade         object
#  6   genero             object
#  7   tpoenvolvido       object
#  8   gravidadelesao     object
#  9   equipseguranca     object
#  10  indmotorista       object
#  11  suspalcool         object
#  12  qtdeacidente       int64
#  13  qtdeenvolvidos     int64
#  14  qtdeobitos         int64
#  15  qtdeferidosilesos  int64
# dtypes: int64(6), object(10)
# memory usage: 604.5+ MB

# %%
TipoVeiculo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3751357 entries, 0 to 3751356
# Data columns (total 4 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   numacidente         int64
#  1   tipoveiculo         object
#  2   indveicestrangeiro  object
#  3   qtdeveiculos        int64
# dtypes: int64(2), object(2)
# memory usage: 114.5+ MB

# %%
Localidade.head(5)
# Out:
#    chvlocalidade  anoreferencia    regiao  uf  codigoibge  \
# 0  MA21004772021           2021  Nordeste  MA     2100477
# 1  SP35392022018           2018   Sudeste  SP     3539202
# 2  PR41285002021           2021       Sul  PR     4128500
# 3  TO17148802018           2018     Norte  TO     1714880
# 4  SP35488072019           2019   Sudeste  SP     3548807
#
#                 municipio regiaometropolitana  qtdehabitantes  frotatotal  \
# 0  Alto Alegre do Pindaré                 Não           32114      3711.0
# 1             Pirapozinho                 Não           27295     15898.0
# 2          Wenceslau Braz                 Não           19285     12181.0
# 3             Nova Olinda                 Não           11719      3168.0
# 4      São Caetano do Sul                 Sim          161127    148316.0
#
#    frotacirculante
# 0           2062.0
# 1           9767.0
# 2           7635.0
# 3           2213.0
# 4          80739.0

# %%
TipoVeiculo.head(5)
# Out:
#    numacidente  tipoveiculo indveicestrangeiro  qtdeveiculos
# 0      2199093    Automóvel      Não Informado             1
# 1      2915784    Automóvel      Não Informado             1
# 2      2286572  Caminhonete      Não Informado             1
# 3      2684970  Caminhonete                Não             1
# 4      2368845    Automóvel      Não Informado             2

# %%
Acidentes.head(5)
# Out:
#    numacidente  chvlocalidade          datacidente ufacidente  anoacidente  \
# 0      1883985  AC12004012018  2018-01-01 00:00:00         AC         2018
# 1      2191869  AC12004012018  2018-01-01 00:00:00         AC         2018
# 2       442465  AC12004012018  2018-01-01 00:00:00         AC         2018
# 3      2532603  AC12007082018  2018-01-01 00:00:00         AC         2018
# 4      3199107  AC12004012018  2018-01-01 00:00:00         AC         2018
#
#    codigoibge      diasemana    fasedia tpacidente condmeteorologica  ...  \
# 0     1200401  Segunda-feira      Tarde    Colisão             Claro  ...
# 1     1200401  Segunda-feira  Madrugada    Colisão             Claro  ...
# 2     1200401  Segunda-feira  Madrugada    Colisão             Claro  ...
# 3     1200708  Segunda-feira      Manhã    Colisão             Claro  ...
# 4     1200401  Segunda-feira      Tarde    Colisão             Claro  ...
#
# ...

# %%
Vitimas.head(5)
# Out:
#    numacidente  chvlocalidade          datacidente ufacidente  anoacidente  \
# 0      1883985  AC12004012018  2018-01-01 00:00:00         AC         2018
# 1      2532603  AC12007082018  2018-01-01 00:00:00         AC         2018
# 2      2532603  AC12007082018  2018-01-01 00:00:00         AC         2018
# 3      3199107  AC12004012018  2018-01-01 00:00:00         AC         2018
# 4      2191869  AC12004012018  2018-01-01 00:00:00         AC         2018
#
#            faixaidade     genero tpoenvolvido gravidadelesao equipseguranca  \
# 0  Entre 30 e 34 anos  Masculino    Motorista  Não Informado  Não Informado
# 1       Não informado  Masculino    Motorista  Não Informado  Não Informado
# 2  Entre 25 e 29 anos  Masculino    Motorista  Não Informado  Não Informado
# 3  Entre 50 e 54 anos  Masculino    Motorista  Não Informado  Não Informado
# 4  Entre 25 e 29 anos  Masculino    Motorista  Não Informado  Não Informado
#
# ...

# %%
Dados_Sinistros = Dados_Sinistros.merge(municipio[['','NO_PAIS']],on='CO_PAIS',how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1621164481.py in <cell line: 0>()
# ----> 1 Localidade_Acidentes = exp_final.merge(exppais[['CO_PAIS','NO_PAIS']],on='CO_PAIS',how='left')
#
# NameError: name 'exp_final' is not defined
